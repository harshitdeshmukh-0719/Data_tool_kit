# %% [markdown]
# <a href="https://colab.research.google.com/github/harshitdeshmukh-0719/Data_tool_kit/blob/main/data_tool_kit.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Demonstrate three different methods for creating identical 2D arrays in NumPy Provide the code for each method and the final output after each method?

# Solution :

# 1. Soln:

import numpy as np

array1 = np.full((3, 3), 7)
print(array1)


# 2. Soln:

import numpy as np

array2 = np.ones((3, 3)) * 7
print(array2)


#  3. Soln:

import numpy as np

array3 = np.array([[7, 7, 7], [7, 7, 7], [7, 7, 7]])
print(array3)
# Out:
# [[7. 7. 7.]
#  [7. 7. 7.]
#  [7. 7. 7.]]

# %%
# 2. Using the Numpy function, generate an array of wRR evenly spaced numPers Petween w and wR and Reshape that wD array into a 2D array?

# Solution :

import numpy as np

w = 0
wR = 10
numPers = 12
rows = 3
cols = 4
array_1d = np.linspace(w, wR, numPers)
array_2d = array_1d.reshape(rows, cols)
print(array_2d)
# Out:
# [[ 0.          0.90909091  1.81818182  2.72727273]
#  [ 3.63636364  4.54545455  5.45454545  6.36363636]
#  [ 7.27272727  8.18181818  9.09090909 10.        ]]

# %%
# 3. Explain the following termsg M The difference in npYarray, npYasarray and npYasanyarrayX

# Solution :

# 1. Solution :

 # np.array
# Creates a new NumPy array from an object.

import numpy as np

lst = [1, 2, 3]
arr = np.array(lst)
print(arr)
existing_array = np.array(arr)
print(existing_array is arr)

# 2. Solution :


# np.asarray
# Converts the input to a NumPy array, but does not make a copy if the input is already an ndarray.
import numpy as np

lst = [1, 2, 3]
arr = np.asarray(lst)
print(arr)
existing_array = np.asarray(arr)
print(existing_array is arr)

# 3. solution :

# np.asanyarray
# Converts the input to a NumPy array, but retains subclasses of ndarray (such as matrix or masked_array).
import numpy as np

lst = [1, 2, 3]
arr = np.asanyarray(lst)
print(arr)

existing_array = np.asanyarray(arr)
print(existing_array is arr)
matrix = np.matrix([[1, 2], [3, 4]])
matrix_array = np.asanyarray(matrix)
print(type(matrix_array))
# Out:
# [1 2 3]
# True

# %%
# 4. Generate a 3*3 array with random floating-point numbers Between 5 and 20 . Then, round each number in the array to 2 decimal places.
import numpy as np

random_array = np.random.uniform(5, 20, (3, 3))
rounded_array = np.round(random_array, 2)
print(rounded_array)
# Out:
# [[18.83  8.09  7.72]
#  [ 7.26  9.06 10.89]
#  [19.31 13.55  8.44]]

# %%
# 5. Create a NumPy array with random integers between w and wR of shape (., )) After creating the array perform the following operations:
# a)Extract all even integers from array.
# b)Extract all odd integers from arrayX

# Solution :

import numpy as np

array = np.random.randint(1, 101, (3, 4))

print("Original Array:")
print(array)

even_numbers = array[array % 2 == 0]

odd_numbers = array[array % 2 != 0]

print("\nEven Numbers:", even_numbers)
print("Odd Numbers:", odd_numbers)
# Out:
# Original Array:
# [[25 57 91 15]
#  [61 52 89 42]
#  [13 70 19 91]]
#
# Even Numbers: [52 42 70]
# Odd Numbers: [25 57 91 15 61 89 13 19 91]

# %%
# 6. Create a 3D NumPy array of shape (3,3,3) containing random integers between 1 and 10 Perform the following operations:
# a) Find the indices of the maximum values along each depth level (third axis).
# b) Perform element-wise multiplication of between both arrayX

# Solution :

import numpy as np

array = np.random.randint(1, 101, (3, 4, 5))

max_indices = np.argmax(array, axis=2)

elementwise_multiplication = array * max_indices[:, :, np.newaxis]

print("Original Array:")
print(array)

print("\nIndices of maximum values along each depth level:")
print(max_indices)

print("\nElement-wise multiplication between array and max indices:")
print(elementwise_multiplication)
# Out:
# Original Array:
# [[[ 55  68  56  95  79]
#   [ 57  58   6  96  14]
#   [ 94  56  31  74  51]
#   [ 43  72  51   6   5]]
#
#  [[ 61  63 100  65  63]
#   [ 86   8  58  16  49]
#   [ 61  66  67  78  22]
#   [ 61  38  97  78   9]]
#
#  [[ 58  89  11  92   2]
#   [ 96  11  46  54  40]
#   [ 33  66  20  25   6]
#   [ 67  76  48  38  17]]]
#
# Indices of maximum values along each depth level:
# [[3 3 0 1]
#  [2 0 3 2]
#  [3 0 1 1]]
#
# Element-wise multiplication between array and max indices:
# [[[165 204 168 285 237]
#   [171 174  18 288  42]
#   [  0   0   0   0   0]
#   [ 43  72  51   6   5]]
#
#  [[122 126 200 130 126]
#   [  0   0   0   0   0]
#   [183 198 201 234  66]
#   [122  76 194 156  18]]
#
#  [[174 267  33 276   6]
#   [  0   0   0   0   0]
#   [ 33  66  20  25   6]
#   [ 67  76  48  38  17]]]

# %%
 #7. Clean and transform the 'Phone' column in the sample dataset to remove non-numeric characters and convert it to a numeric data type Also display the taPle attriPutes and data types of each column.

# Solution :

import pandas as pd
df = pd.read_csv("People Data.csv")

# Handling missing values and cleaning the 'Phone' column
df['Phone'] = df['Phone'].fillna('').str.replace('[^\d]', '', regex=True)

# Convert the cleaned 'Phone' column to integers
df['Phone'] = pd.to_numeric(df['Phone'], errors='coerce')

# Displaying table attributes and data types of each column
print("\nTable attributes:")
print(df.info())

# Displaying data types of each column
print("\nData types of each column:")
print(df.dtypes)

# Displaying the updated DataFrame
print("\nUpdated DataFrame:")
print(df.head())
# Out:
# Table attributes:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 10 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Index          1000 non-null   int64
#  1   User Id        1000 non-null   object
#  2   First Name     1000 non-null   object
#  3   Last Name      1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Email          1000 non-null   object
#  6   Phone          979 non-null    float64
#  7   Date of birth  1000 non-null   object
#  8   Job Title      1000 non-null   object
#  9   Salary         1000 non-null   int64
# dtypes: float64(1), int64(2), object(7)
# memory usage: 78.2+ KB
# None
#
# Data types of each column:
# Index              int64
# User Id           object
# First Name        object
# Last Name         object
# Gender            object
# Email             object
# Phone            float64
# Date of birth     object
# ...

# %% [markdown]
# 8. Perform the following tas\s using people dataset:
#
#  a) Read the 'dataYcsv' file using pandas, skipping the first 50 rows.
#
#  b) Only read the columns: 'Last Name', ‘Gender’,’Email’,‘Phone’ and ‘Salary’ from the file.
#
#  c) Display the first 10 rows of the filtered dataset.
#
#  d) Extract the ‘Salary’' column as a Series and display its last 5 values

# %%
# 8. Perform the following tas\s using people dataset:
# a) Read the 'dataYcsv' file using pandas, skipping the first 50 rows.
# b) Only read the columns: 'Last Name', ‘Gender’,’Email’,‘Phone’ and ‘Salary’ from the file.
# c) Display the first 10 rows of the filtered dataset.
# d) Extract the ‘Salary’' column as a Series and display its last 5 values

# Solution :

import pandas as pd
import os

print("Files in the current directory:", os.listdir('.'))

file_path = '/content/People Data.csv'
if not os.path.isfile(file_path):
    print(f"File '{file_path}' not found. Please check the file path.")
else:
    columns_to_read = ['Last Name', 'Gender', 'Email', 'Phone', 'Salary']

    df = pd.read_csv(file_path, usecols=columns_to_read, skiprows=50)

    print("First 10 rows of the filtered dataset:")
    print(df.head(10))

    salary_series = df['Salary']

    print("\nLast 5 values of the 'Salary' column:")
    print(salary_series.tail(5))

# %%
# 9. Filter and select rows from the People_Dataset, where the “Last Name' column contains the name 'Duke', 'Gender' column contains the word Female and
#    ‘Salary’ should be less than 85000.

# Solution :

import pandas as pd
df = pd.read_csv("/content/People Data.csv")

filtered_df = df[(df['Last Name'].str.contains('Duke')) &
                 (df['Gender'] == 'Female') &
                 (df['Salary'] < 85000)]
filtered_df

# %%
# 10. Create a 7*5 Dataframe in Pandas using a series generated from 35 random integers between 1 to 6?

# Solution :
import numpy as np
import pandas as pd

# Generate a series of random integers between 10 and 50
random_series = np.random.randint(10, 51, size=49)  # 7 * 7 = 49 elements

# Reshape the series into a 7x7 DataFrame
df = pd.DataFrame(random_series.reshape(7, 7))
df
# Out:
#     0   1   2   3   4   5   6
# 0  34  27  37  26  33  22  17
# 1  46  11  45  27  13  13  42
# 2  21  30  22  36  11  48  13
# 3  14  48  12  50  32  10  21
# 4  37  35  22  41  40  32  47
# 5  31  41  13  27  10  49  38
# 6  45  26  36  49  13  33  15

# %%
# 11. Create two different Series, each of length 50, with the following criteria:
# a) The first Series should contain random numbers ranging from 10 to 50.

# b) The second Series should contain random numbers ranging from 100 to 1000.

# c) Create a DataFrame by 'oining these Series by column, and, change the names of the columns to 'col1', 'col2', etc.

# Solution :

import pandas as pd
import numpy as np
series1 = pd.Series(np.random.randint(10, 51, size=50))
series2 = pd.Series(np.random.randint(100, 1001, size=50))
df = pd.DataFrame({'col1': series1, 'col2': series2})
print(df)
# Out:
#     col1  col2
# 0     45   418
# 1     19   280
# 2     50   942
# 3     48   724
# 4     50   451
# 5     49   162
# 6     13   389
# 7     31   443
# 8     50   746
# 9     11   980
# 10    47   193
# 11    40   845
# 12    45   320
# 13    34   849
# 14    40   759
# 15    21   398
# 16    43   995
# 17    29   346
# 18    21   799
# 19    46   874
# 20    37   432
# 21    27   978
# 22    18   555
# 23    34   386
# 24    45   115
# 25    42   561
# 26    20   252
# 27    11   222
# 28    35   269
# 29    14   702
# 30    48   216
# 31    13   848
# 32    16   539
# 33    10   714
# 34    44   147
# 35    42   352
# 36    17   225
# 37    40   777
# 38    46   940
# 39    49   798
# 40    10   377
# 41    19   134
# 42    27   433
# 43    37   115
# 44    37   582
# 45    14   164
# 46    35   628
# 47    35   338
# 48    41   960
# 49    13   379

# %%
# # 12. Create two different Series, each of length 50, with the following criteria:
# a) The first Series should contain random numbers ranging from 10 to 50.

# b) The second Series should contain random numbers ranging from 100 to 1000.

# c) Create a Data Frame by 'joining these Series by column, and, change the names of the columns to 'col1', 'col2', etc.

# Solution :

import pandas as pd
import numpy as np

series1 = pd.Series(np.random.randint(10, 51, size=50))
series2 = pd.Series(np.random.randint(100, 1001, size=50))
df = pd.DataFrame({'col1': series1, 'col2': series2})
print(df)
# Out:
#     col1  col2
# 0     33   469
# 1     18   389
# 2     38   817
# 3     24   648
# 4     37   448
# 5     14   960
# 6     49   968
# 7     30   119
# 8     37   406
# 9     28   277
# 10    48   679
# 11    22   311
# 12    41   505
# 13    18   121
# 14    29   592
# 15    29   781
# 16    13   895
# 17    45   577
# 18    46   109
# 19    19   713
# 20    28   202
# 21    38   143
# 22    39   943
# 23    36   854
# 24    23   590
# 25    28   283
# 26    40   336
# 27    27   405
# 28    11   261
# 29    45   585
# 30    26   100
# 31    23   848
# 32    15   169
# 33    16   884
# 34    33   932
# 35    25   222
# 36    33   153
# 37    25   751
# 38    29   725
# 39    37   714
# 40    18   490
# 41    10   572
# 42    20   999
# 43    11   406
# 44    24   244
# 45    40   147
# 46    23   514
# 47    16   830
# 48    21   997
# 49    12   596

# %% [markdown]
# 13. Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the
# following tasks using Matplotlib and NumPy:
#
# a) Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'.
#
# b) Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.
#
# c) Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'.
#
# d) Label the x-axis as 'X-axis' and the y-axis as 'Y-axis'.
#
# e) Set the title of the plot as 'Advanced Scatter Plot of Random Values'.
#
# f) Display a legend for the scatter plot, the horizontal line, and the vertical line.

# %%
# 13. Create two NumPy arrays, x and y, each containing 100 random float values between 0 and 1. Perform the following tasks using Matplotlib and NumPy:
# a) Create a scatter plot using x and y, setting the color of the points to red and the marker style to 'o'.
# b) Add a horizontal line at y = 0.5 using a dashed line style and label it as 'y = 0.5'.
# c) Add a vertical line at x = 0.5 using a dotted line style and label it as 'x = 0.5'.
# d) Label the x-axis as 'X-axis' and the y-axis as 'Y-axis'.
# e) Set the title of the plot as 'Advanced Scatter Plot of Random Values'.
# f) Display a legend for the scatter plot, the horizontal line, and the vertical line.

# Solution :

import numpy as np
import matplotlib.pyplot as plt

x = np.random.rand(100)
y = np.random.rand(100)

plt.scatter(x, y, color='red', marker='o', label='Scatter Plot')
plt.axhline(y=0.5, color='blue', linestyle='--', label='y = 0.5')
plt.axvline(x=0.5, color='green', linestyle=':', label='x = 0.5')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Advanced Scatter Plot of Random Values')
plt.legend()
plt.show()

# %%
#  14. Create a time-series dataset in a Pandas Data Frame with columns: 'Date', 'Temperature', 'Humidity' and Perform the following tasks using Matplotlib:
# a) Plot the 'Temperature' and 'Humidity' on the same plot with different y-axes (left y-axis for 'Temperature' and right y-axis for 'Humidity').
# b) Label the x-axis as 'Date'.
# c) Set the title of the plot as 'Temperature and Humidity Over Time'.

# Solution :

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dates = pd.date_range('2022-01-01', periods=100)
temperature = np.random.normal(25, 5, 100)
humidity = np.random.normal(50, 10, 100)

data = {
    'Date': dates,
    'Temperature': temperature,
    'Humidity': humidity
}

df = pd.DataFrame(data)

fig, ax1 = plt.subplots()

color = 'tab:red'
ax1.set_xlabel('Date')
ax1.set_ylabel('Temperature', color=color)
ax1.plot(df['Date'], df['Temperature'], color=color)
ax1.tick_params(axis='y', labelcolor=color)

ax2 = ax1.twinx()
color = 'tab:blue'
ax2.set_ylabel('Humidity', color=color)
ax2.plot(df['Date'], df['Humidity'], color=color)
ax2.tick_params(axis='y', labelcolor=color)

plt.xlabel('Date')
plt.title('Temperature and Humidity Over Time')

plt.show()

# %%
# 15.Create a NumPy array data containing 1000 samples from a normal distribution. Perform the following tasks using Matplotlib: a) Plot a histogram of the data with 30 bins.
# b) Overlay a line plot representing the normal distribution's probability density function (PDF).
# c) Label the x-axis as 'Value' and the y-axis as 'Frequency/Probability'.
# d) Set the title of the plot as 'Histogram with PDF Overlay'.
 # Solution :

import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(size=1000)

plt.hist(data, bins=30, density=True, alpha=0.7, label='Histogram')

mu, std = np.mean(data), np.std(data)
xmin, xmax = plt.xlim()
x = np.linspace(xmin, xmax, 100)
p = (1 / (std * np.sqrt(2 * np.pi))) * np.exp(-0.5 * ((x - mu) / std) ** 2)
plt.plot(x, p, 'k', linewidth=2, label='PDF')

plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

plt.title('Histogram with PDF Overlay')

plt.legend()

plt.show()

# %%
# 16. Set the title of the plot as 'Histogram with PDF Overlay
# Solution :

import numpy as np
import matplotlib.pyplot as plt

data = np.random.normal(size=1000)

plt.hist(data, bins=30, density=True, alpha=0.7, label='Histogram')

mu, std = np.mean(data), np.std(data)
x = np.linspace(min(data), max(data), 100)
pdf = 1/(std * np.sqrt(2 * np.pi)) * np.exp(-(x - mu)**2 / (2 * std**2))
plt.plot(x, pdf, 'k', linewidth=2, label='PDF')

plt.xlabel('Value')
plt.ylabel('Frequency/Probability')

plt.title('Histogram with PDF Overlay')

plt.legend()

plt.show()

# %%
# 17. Create a Seaborn scatter plot of two random arrays, color points based on their position relative to the origin (quadrants), add a legend, label the axes, and set the title as 'Quadrant-wise Scatter Plot'.

# Solution :

import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

x = np.random.randn(100)
y = np.random.randn(100)

quadrants = []
for i in range(len(x)):
    if x[i] > 0 and y[i] > 0:
        quadrants.append('Quadrant I')
    elif x[i] < 0 and y[i] > 0:
        quadrants.append('Quadrant II')
    elif x[i] < 0 and y[i] < 0:
        quadrants.append('Quadrant III')
    else:
        quadrants.append('Quadrant IV')

data = {
    'x': x,
    'y': y,
    'Quadrant': quadrants
}
df = pd.DataFrame(data)

plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='x', y='y', hue='Quadrant', palette='deep')

plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Quadrant-wise Scatter Plot')
plt.legend(title='Quadrant')
plt.show()

# %%
# 18. With Bokeh, plot a line chart of a sine wave function, add grid lines, label the axes, and set the title as 'Sine Wave Function.
import numpy as np
import matplotlib.pyplot as plt
x = np.linspace(0, 4 * np.pi, 100)
y = np.sin(x)
plt.figure(figsize=(10, 6))
plt.plot(x, y, label='sin(x)', color='blue', linewidth=2)
plt.grid(True)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Sine Wave Function')
plt.legend()
plt.show()

# %%
# 19. Using Bokeh, generate a bar chart of randomly generated categorical data, color bars based on their values, add hover tooltips to display exact values, label the axes, and set the title as 'Random Categorical Bar Chart.
# Solution :

import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Generate random data
categories = ['A', 'B', 'C', 'D', 'E']
values = np.random.randint(1, 100, size=5)

# Create DataFrame
df = pd.DataFrame({'categories': categories, 'values': values})

# Create bar plot
plt.figure(figsize=(8, 5))
sns.barplot(x='categories', y='values', data=df, palette='viridis')

# Add value labels on bars
for i in range(len(df)):
    plt.text(i, df['values'][i] + 1, df['values'][i], ha='center')

# Label axes and set title
plt.xlabel('Categories')
plt.ylabel('Values')
plt.title('Random Categorical Bar Chart')
plt.show()
# Out:
# <ipython-input-12-de4404545041>:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='categories', y='values', data=df, palette='viridis')

# %%
# 20. Using Plotly, create a basic line plot of a randomly generated dataset, label the axes, and set the title as 'Simple Line Plot.
# Solution :

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

x = np.linspace(0, 10, 100)
y = np.random.randn(100)

df = pd.DataFrame({'x': x, 'y': y})

plt.figure(figsize=(10, 6))
plt.plot(df['x'], df['y'], label='Random Data', color='blue')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Simple Line Plot')
plt.legend()
plt.show()

# %% [markdown]
# 21. Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set
# the title as 'Interactive Pie Chart

# %%
# 21. Using Plotly, create an interactive pie chart of randomly generated data, add labels and percentages, set the title as 'Interactive Pie Chart
# Solution :

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# Generate random data
np.random.seed(0)
categories = ['Category A', 'Category B', 'Category C', 'Category D', 'Category E']
values = np.random.randint(10, 100, size=len(categories))

# Create a DataFrame
df = pd.DataFrame({'categories': categories, 'values': values})

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(df['values'], labels=df['categories'], autopct='%1.1f%%', startangle=140, colors=plt.cm.viridis(np.linspace(0, 1, len(categories))))

# Set the title
plt.title('Interactive Pie Chart')

# Show the plot
plt.show()
